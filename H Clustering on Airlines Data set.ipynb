# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
et=pd.read_csv("eastwestairlines.csv")

# %%
et.head()
# Out:
#    ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0   1    28143           0          1          1          1          174
# 1   2    19244           0          1          1          1          215
# 2   3    41354           0          1          1          1         4123
# 3   4    14776           0          1          1          1          500
# 4   5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
et.columns
# Out:
# Index(['ID', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award'],
#       dtype='object')

# %%
et.describe()
# Out:
#                 ID       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
et.isnull().sum() # Checking the null values
# Out:
# ID                   0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %%
def norm_func(i):
    x = (i-i.min())	/	(i.max()	-	i.min())
    return (x)

# %%
df_norm = norm_func(et.iloc[:,1:]) # Normalizing the data
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
from scipy.cluster.hierarchy import linkage 

import scipy.cluster.hierarchy as sch # for creating dendrogram

# %%
type(df_norm) ## Checking the which data type after converting the normalization
# Out:
# pandas.core.frame.DataFrame

# %%
#p = np.array(df_norm) # converting into numpy array format 
z = linkage(df_norm, method="average",metric="euclidean") ## distance between the clusters , method= average 

plt.figure(figsize=(15, 5));plt.title('Hierarchical Clustering Dendrogram');plt.xlabel('Index');plt.ylabel('Distance')
sch.dendrogram(
    z,
    leaf_rotation=0.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
#p = np.array(df_norm) # converting into numpy array format 
z = linkage(df_norm, method="complete",metric="euclidean") ## distance between the clusters , method= complete

plt.figure(figsize=(15, 5));plt.title('Hierarchical Clustering Dendrogram');plt.xlabel('Index');plt.ylabel('Distance')
sch.dendrogram(
    z,
    leaf_rotation=0.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
#p = np.array(df_norm) # converting into numpy array format 
z = linkage(df_norm, method="single",metric="euclidean") ## distance between the clusters , method= single

plt.figure(figsize=(15, 5));plt.title('Hierarchical Clustering Dendrogram');plt.xlabel('Index');plt.ylabel('Distance')
sch.dendrogram(
    z,
    leaf_rotation=0.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering 
h_complete = AgglomerativeClustering(n_clusters=5,linkage='single',affinity = "euclidean").fit(df_norm)

# %%
cluster_labels=pd.Series(h_complete.labels_)
cluster_labels
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 3994    1
# 3995    1
# 3996    1
# 3997    0
# 3998    0
# Length: 3999, dtype: int64

# %%
et['clust']=cluster_labels # creating a  new column and assigning it to new column 
et = et.iloc[:,]

# %%
et.head(100)
# Out:
#      ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     1    28143           0          1          1          1          174
# 1     2    19244           0          1          1          1          215
# 2     3    41354           0          1          1          1         4123
# 3     4    14776           0          1          1          1          500
# 4     5    97752           0          4          1          1        43300
# ..  ...      ...         ...        ...        ...        ...          ...
# 95   98    16796           0          1          1          1         2875
# 96   99    57346           0          1          1          1         5560
# 97  100   102062           0          4          1          1        44247
# 98  101    22324           0          1          1          1         1375
# 99  102    64824           0          3          1          1        20184
#
# ...

# %%
cluster_labels
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 3994    1
# 3995    1
# 3996    1
# 3997    0
# 3998    0
# Length: 3999, dtype: int64

# %%
et['clust']=cluster_labels

# %%
et['clust']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 3994    1
# 3995    1
# 3996    1
# 3997    0
# 3998    0
# Name: clust, Length: 3999, dtype: int64

# %%
et.iloc[:,1:].groupby(et.clust).mean()
# Out:
#              Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clust
# 0       59807.839555   87.602462   1.705322   1.013900   1.008737
# 1       97125.211773  240.345737   2.664411   1.015562   1.015562
# 2      160114.000000  500.000000   1.000000   1.000000   1.000000
# 3        8557.000000    0.000000   1.000000   1.000000   1.000000
# 4       15835.000000    0.000000   2.000000   1.000000   5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clust
# 0       10227.689039     9.142971         226.292295         0.652502
# 1       28703.769959    15.742219         837.970230         2.566982
# 2       71954.000000    86.000000       30817.000000        53.000000
# 3      200622.000000     5.000000         622.000000         3.000000
# 4      112171.000000    16.000000           0.000000         0.000000
#
#        Days_since_enroll  Award  clust
# clust
# 0            3820.652105    0.0    0.0
# 1            4628.257104    1.0    1.0
# ...

# %%
et
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# # CONCLUSION :  hence its very diificult to say in cluster how many categories because it is big data
# # so we go to the K Means Clustering
